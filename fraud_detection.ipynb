# %% [markdown]
# Preliminary class construction for the Assemble.AdaBoost model, based on Exploiting Unlabeled Data in Ensemble Methods, Bennett et al.

# %%
from sklearn import preprocessing as pp
import math as m
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('mle_fraud_test.csv', sep=';', index_col=0)
data.head()
# Out:
#              user_id order_created_datetime     amount  total_amount_14days  \
# order_id
# 1          499120842       15/01/2019 00:00  23.754760             0.000000
# 2          425189022       15/01/2019 00:00  17.903987            20.805420
# 3          975417854       15/01/2019 00:00  16.450540            17.887367
# 4         1836800872       15/01/2019 00:00  16.450540             0.000000
# 5         3411980586       15/01/2019 00:00  16.530277            17.892307
#
#           email_handle_length  email_handle_dst_char  total_nb_orders_player  \
# order_id
# 1                          11                     10                       3
# 2                          13                      9                      29
# 3                          13                     11                       4
# 4                          13                     10                       4
# 5                           5                      5                      46
#
# ...

# %%
class fraudDetectionInputData():
    
    labelledData = pd.DataFrame()
    unlabbeledData = pd.DataFrame()
    
    labels = pd.Series()
    
    distanceMatrix = [[]]
    norm = 'l1'
    
    def __init__():
        pass
    
    def importData(data):
        cols = data.columns
        
        tmp = fraudDetectionToInt(data)
        tmp = riskCountryToInt(tmp)
        tmp = normalizeData(tmp)
        
        labelledData   = tmp[tmp['transaction_status'] != -1][[col for col in cols if col != 'transaction_status']]
        unlabelledData = tmp[tmp['transaction_status'] == -1][[col for col in cols if col != 'transaction_status']]
        labels         = tmp['transaction_status']
        
        
    def riskCountryToInt(data):
        tmp = data['geographic_distance_risk'].apply(lambda s : 1 if s == 'YES' else 0)
        return tmp
        
        
    def fraudDetectedToInt(data):
        tmp = data['transaction_status'].apply(lambda s : 1 if s == 'FRAUD' else (0 if s == 'LEGIT' else -1))
        return tmp
        
        
    def normalizeData(data):
        
        cols = data.columns
       
        tmp = pd.DataFrame(data[[col for col in cols if col != 'transaction_status']],
                           columns = [col for col in cols if col != 'transaction_status'])
        tmp = pd.concat([tmp, data['transaction_status']])
        return tmp
    
    def buildDistanceMatrix():
        l = len(labelledData)
        u = len(unlabelledData)
        
        for i in range(u):
            for j in range(l):
                distanceMatrix[i][j] =  sum(m.fabs(labelledData[j] - unlabelledData[i]))
                
    def buildPseudoClasses():
        l = len(distanceMatrix[0])
        u = len(distanceMatrix)
        
        for i in range(u):
            labels[i + l] = labels[np.argmin(distanceMatrix[i])]

# %%
fdid = fraudDetectionInputData()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-5db95ac6a2f3> in <module>
# ----> 1 fdid = fraudDetectionInputData()
#
# TypeError: __init__() takes 0 positional arguments but 1 was given

# %%
class assembleAdaboost():

    alpha = 1
    beta = 0.5
    
    pretrainedClassifiers = []
    newClassifiers = sklearn.model
    currentClassifier = sklearn.model
    weigths = 0
    



    
    def __init__(a, b):
        alpha = a
        beta = b
        
    def addModel(model):
        models.append(model)
